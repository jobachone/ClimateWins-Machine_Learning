# %% [markdown]
# # 2.1 Dendrograms using reduced dataset
#
# ## Contents:
#
# ### 1. Importing Libraries and Data
#
# ### 2. Data Wrangling and Scaling
# - Scaled to 1993 only
# ### 3. Dendrograms
# - Madrid vs Munich
#     - Single
#     - Complete
#     - Average
#     - Ward
# - All Stations
#     - Ward
#     - Average
#     - Complete
#     - Single
# - Heathrow, Madrid, Gdansk
#     - Single
#     - Complete
#     - Average
#     - Ward
#
# ### 4. Principal Component Analysis

# %% [markdown]
# ### 1. Importing Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# Setting Path 

path = r'/Users/jeremyobach/Documents/Data Analytics/CareerFoundry/Specialization - Machine Learning/Real World Applications of Machine Learning/ML Achievement 2 MASTER FOLDER'
#checking path set correctly
path
# Out:
# '/Users/jeremyobach/Documents/Data Analytics/CareerFoundry/Specialization - Machine Learning/Real World Applications of Machine Learning/ML Achievement 2 MASTER FOLDER'

# %%
pleasant = pd.read_csv (os.path.join(path, '02 Data', 'pleasant_wx_predictions.csv'), index_col = False)

# %%
pleasant.shape
# Out:
# (22950, 16)

# %%
reduced =  pd.read_csv (os.path.join(path, '02 Data', '1993_PCA.csv'), index_col = False)

# %%
reduced.head()
# Out:
#         PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0  13.015909 -7.940344 -0.538039 -0.697534 -0.696364  0.169871 -1.865393
# 1  14.019071 -8.865594  2.568640  0.109120  0.782248 -0.061547  0.572058
# 2  14.717246 -9.332488  2.859560  0.677864  0.142365 -0.596494  1.009220
# 3  13.957263 -6.790032 -0.738928  1.768395 -0.808804  2.259599  0.196689
# 4  11.537669 -4.770651 -5.499279  4.182413  1.490860  0.568713  2.109372
#
#        PCA8      PCA9     PCA10     PCA11
# 0  0.941023  1.047694  2.585846  2.317299
# 1  1.040433  3.383280  4.889953  2.734790
# 2  0.051100  1.734585  4.398625  3.235790
# 3 -0.067423  1.087669  3.951186 -0.423698
# 4  0.026904  0.826765  3.799985 -0.278513

# %%
reduced = reduced.drop(columns =['Unnamed: 0'])

# %% [markdown]
# ### 2. Rerunning Dendrogram code with Reduced Dataset

# %%
distance_single = linkage(reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10',
'PCA11']],method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Single Method",fontsize=18)
plt.show()

# %%
distance_single = linkage(reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10',
'PCA11',]],method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Complete Method",fontsize=18)
plt.show()

# %%
distance_single = linkage(reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10',
'PCA11',]],method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Average Method",fontsize=18)
plt.show()

# %%
distance_single = linkage(reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10',
'PCA11',]],method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Ward Method",fontsize=18)
plt.show()
